# %%
import keras
keras.__version__
# Out:
# '3.10.0'

# %% [markdown]
# # Introduction to generative adversarial networks
#
# This notebook contains the second code sample found in Chapter 8, Section 5 of [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python?a_aid=keras&a_bid=76564dff). Note that the original text features far more content, in particular further explanations and figures: in this notebook, you will only find source code and related comments.
#
# ---
# [...]

# %% [markdown]
# ## A schematic GAN implementation
#
#
# In what follows, we explain how to implement a GAN in Keras, in its barest form -- since GANs are quite advanced, diving deeply into the
# technical details would be out of scope for us. Our specific implementation will be a deep convolutional GAN, or DCGAN: a GAN where the
# generator and discriminator are deep convnets. In particular, it leverages a `Conv2DTranspose` layer for image upsampling in the generator.
#
# We will train our GAN on images from CIFAR10, a dataset of 50,000 32x32 RGB images belong to 10 classes (5,000 images per class). To make
# things even easier, we will only use images belonging to the class "frog".
#
# Schematically, our GAN looks like this:
#
# * A `generator` network maps vectors of shape `(latent_dim,)` to images of shape `(32, 32, 3)`.
# * A `discriminator` network maps images of shape (32, 32, 3) to a binary score estimating the probability that the image is real.
# * A `gan` network chains the generator and the discriminator together: `gan(x) = discriminator(generator(x))`. Thus this `gan` network maps
# latent space vectors to the discriminator's assessment of the realism of these latent vectors as decoded by the generator.
# * We train the discriminator using examples of real and fake images along with "real"/"fake" labels, as we would train any regular image
# classification model.
# * To train the generator, we use the gradients of the generator's weights with regard to the loss of the `gan` model. This means that, at
# every step, we move the weights of the generator in a direction that will make the discriminator more likely to classify as "real" the
# images decoded by the generator. I.e. we train the generator to fool the discriminator.

# %% [markdown]
# ## A bag of tricks
#
#
# Training GANs and tuning GAN implementations is notoriously difficult. There are a number of known "tricks" that one should keep in mind.
# Like most things in deep learning, it is more alchemy than science: these tricks are really just heuristics, not theory-backed guidelines.
# They are backed by some level of intuitive understanding of the phenomenon at hand, and they are known to work well empirically, albeit not
# necessarily in every context.
#
# Here are a few of the tricks that we leverage in our own implementation of a GAN generator and discriminator below. It is not an exhaustive
# list of GAN-related tricks; you will find many more across the GAN literature.
#
# * We use `tanh` as the last activation in the generator, instead of `sigmoid`, which would be more commonly found in other types of models.
# * We sample points from the latent space using a _normal distribution_ (Gaussian distribution), not a uniform distribution.
# * Stochasticity is good to induce robustness. Since GAN training results in a dynamic equilibrium, GANs are likely to get "stuck" in all sorts of ways.
# Introducing randomness during training helps prevent this. We introduce randomness in two ways: 1) we use dropout in the discriminator, 2)
# we add some random noise to the labels for the discriminator.
# * Sparse gradients can hinder GAN training. In deep learning, sparsity is often a desirable property, but not in GANs. There are two things
# that can induce gradient sparsity: 1) max pooling operations, 2) ReLU activations. Instead of max pooling, we recommend using strided
# convolutions for downsampling, and we recommend using a `LeakyReLU` layer instead of a ReLU activation. It is similar to ReLU but it
# relaxes sparsity constraints by allowing small negative activation values.
# * In generated images, it is common to see "checkerboard artifacts" caused by unequal coverage of the pixel space in the generator. To fix
# this, we use a kernel size that is divisible by the stride size, whenever we use a strided `Conv2DTranpose` or `Conv2D` in both the
# generator and discriminator.

# %% [markdown]
# ## The generator
#
#
# First, we develop a `generator` model, which turns a vector (from the latent space -- during training it will sampled at random) into a
# candidate image. One of the many issues that commonly arise with GANs is that the generator gets stuck with generated images that look like
# noise. A possible solution is to use dropout on both the discriminator and generator.

# %%
import keras
from keras import layers
import numpy as np

latent_dim = 32
height = 32
width = 32
channels = 3

generator_input = keras.Input(shape=(latent_dim,))

# First, transform the input into a 16x16 128-channels feature map
x = layers.Dense(128 * 16 * 16)(generator_input)
x = layers.LeakyReLU()(x)
x = layers.Reshape((16, 16, 128))(x)

# Then, add a convolution layer
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# Upsample to 32x32
x = layers.Conv2DTranspose(256, 4, strides=2, padding='same')(x)
x = layers.LeakyReLU()(x)

# Few more conv layers
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# Produce a 32x32 1-channel feature map
x = layers.Conv2D(channels, 7, activation='tanh', padding='same')(x)
generator = keras.models.Model(generator_input, x)
generator.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32768)          │     1,081,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 32768)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 16, 16, 256)    │       819,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 32, 32, 256)    │     1,048,832 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 32, 32, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 256)    │     1,638,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 32, 32, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 256)    │     1,638,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_4 (LeakyReLU)       │ (None, 32, 32, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 32, 32, 3)      │        37,635 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,264,579 (23.90 MB)
#  Trainable params: 6,264,579 (23.90 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## The discriminator
#
#
# Then, we develop a `discriminator` model, that takes as input a candidate image (real or synthetic) and classifies it into one of two
# classes, either "generated image" or "real image that comes from the training set".

# %%
discriminator_input = layers.Input(shape=(height, width, channels))
x = layers.Conv2D(128, 3)(discriminator_input)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Flatten()(x)

# One dropout layer - important trick!
x = layers.Dropout(0.4)(x)

# Classification layer
x = layers.Dense(1, activation='sigmoid')(x)

discriminator = keras.models.Model(discriminator_input, x)
discriminator.summary()

# To stabilize training, we use learning rate decay
# and gradient clipping (by value) in the optimizer.
discriminator_optimizer = keras.optimizers.Adam(learning_rate=0.00015, clipvalue=1.0, beta_1=0.5)
discriminator.compile(optimizer=discriminator_optimizer, loss='binary_crossentropy')
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 30, 30, 128)    │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_5 (LeakyReLU)       │ (None, 30, 30, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 14, 14, 128)    │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_6 (LeakyReLU)       │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 6, 6, 128)      │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_7 (LeakyReLU)       │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 2, 2, 128)      │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_8 (LeakyReLU)       │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 790,913 (3.02 MB)
#  Trainable params: 790,913 (3.02 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## The adversarial network
#
# Finally, we setup the GAN, which chains the generator and the discriminator. This is the model that, when trained, will move the generator
# in a direction that improves its ability to fool the discriminator. This model turns latent space points into a classification decision,
# "fake" or "real", and it is meant to be trained with labels that are always "these are real images". So training `gan` will updates the
# weights of `generator` in a way that makes `discriminator` more likely to predict "real" when looking at fake images. Very importantly, we
# set the discriminator to be frozen during training (non-trainable): its weights will not be updated when training `gan`. If the
# discriminator weights could be updated during this process, then we would be training the discriminator to always predict "real", which is
# not what we want!

# %%
# Set discriminator weights to non-trainable
# (will only apply to the `gan` model)
discriminator.trainable = False

gan_input = keras.Input(shape=(latent_dim,))
gan_output = discriminator(generator(gan_input))
gan = keras.models.Model(gan_input, gan_output)

gan_optimizer = keras.optimizers.Adam(learning_rate=0.0001, clipvalue=1.0, beta_1=0.5)
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')
discriminator.trainable = True
# gan.load_weights('gan.weights.h5')

# %% [markdown]
# ## How to train your DCGAN
#
# Now we can start training. To recapitulate, this is schematically what the training loop looks like:
#
# ```
# for each epoch:
#     * Draw random points in the latent space (random noise).
#     * Generate images with `generator` using this random noise.
#     * Mix the generated images with real ones.
#     * Train `discriminator` using these mixed images, with corresponding targets, either "real" (for the real images) or "fake" (for the generated images).
#     * Draw new random points in the latent space.
#     * Train `gan` using these random vectors, with targets that all say "these are real images". This will update the weights of the generator (only, since discriminator is frozen inside `gan`) to move them towards getting the discriminator to predict "these are real images" for generated images, i.e. this trains the generator to fool the discriminator.
# ```
#
# Let's implement it:

# %%
import os
from keras.preprocessing import image

# Load CIFAR10 data
(x_train, y_train), (_, _) = keras.datasets.cifar10.load_data()

# Select frog images (class 6)
x_train = x_train[y_train.flatten() == 6]

# Normalize data
x_train = x_train.reshape(
    (x_train.shape[0],) + (height, width, channels)).astype('float32') / 127.5 - 1
print(f"x_train average: {np.average(x_train):.4f}, median: {np.median(x_train):.4f}")

iterations = 10000
batch_size = 20
save_dir = 'gan_images'
import shutil
shutil.rmtree(save_dir, ignore_errors=True)
os.makedirs(save_dir, exist_ok=True)
d_losses = []
a_losses = []
steps_plotted = []
average = []
median = []

# Start training loop
start = 0
for step in range(iterations):
    # Sample random points in the latent space
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # Decode them to fake images
    generated_images = generator.predict(random_latent_vectors, verbose=0)
    average.append(np.average(generated_images))
    median.append(np.median(generated_images))

    # Combine them with real images
    stop = start + batch_size
    real_images = x_train[start: stop]
    combined_images = np.concatenate([generated_images, real_images])

    # Assemble labels discriminating real from fake images
    labels = np.concatenate([np.ones((batch_size, 1)),
                             np.zeros((batch_size, 1))])
    # Add random noise to the labels - important trick!
    labels += 0.05 * np.random.random(labels.shape)

    # Train the discriminator
    d_loss = discriminator.train_on_batch(combined_images, labels)

    # sample random points in the latent space
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # Assemble labels that say "all real images"
    misleading_targets = np.zeros((batch_size, 1))

    # Train the generator (via the gan model,
    # where the discriminator weights are frozen)
    a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)
    d_losses.append(d_loss)
    a_losses.append(a_loss)
    steps_plotted.append(step)

    start += batch_size
    if start > len(x_train) - batch_size:
      start = 0

    # Occasionally save / plot
    if step % 100 == 0:
        # Save model weights
        gan.save_weights(f'gan_step_{step}.weights.h5')
        previous_file = f'gan_step_{step - 100}.weights.h5'
        if os.path.exists(previous_file):
            os.remove(previous_file)
        print(f'step {step}, discriminator loss: {d_loss:.4f}, adversarial loss: {a_loss:.4f}')
        print(f"generated_images average: {np.average(generated_images):.4f}, median: {np.median(generated_images):.4f}")

        # Save one generated image
        img = image.array_to_img((generated_images[0] + 1) * 127.5, scale=False)
        img.save(os.path.join(save_dir, 'generated_frog' + str(step) + '.png'))

        # Save one real image, for comparison
        img = image.array_to_img((real_images[0] + 1) * 127.5, scale=False)
        img.save(os.path.join(save_dir, 'real_frog' + str(step) + '.png'))
# Out:
# x_train average: -0.1642, median: -0.2000
# step 0, discriminator loss: 0.6884, adversarial loss: 0.6927
# generated_images average: -0.0015, median: -0.0014
# step 100, discriminator loss: 0.5998, adversarial loss: 0.6488
# generated_images average: -0.3326, median: -1.0000
# step 200, discriminator loss: 0.6015, adversarial loss: 0.7496
# generated_images average: 0.5123, median: 0.7127
# step 300, discriminator loss: 0.6499, adversarial loss: 0.7534
# generated_images average: -0.3170, median: -0.3421
# step 400, discriminator loss: 0.6714, adversarial loss: 0.7394
# generated_images average: -0.1840, median: -0.0540
# step 500, discriminator loss: 0.6855, adversarial loss: 0.7434
# generated_images average: -0.1427, median: -0.0518
# step 600, discriminator loss: 0.6939, adversarial loss: 0.7310
# generated_images average: 0.1361, median: 0.1003
# step 700, discriminator loss: 0.6975, adversarial loss: 0.7174
# generated_images average: -0.2848, median: -0.2914
# step 800, discriminator loss: 0.7040, adversarial loss: 0.7108
# generated_images average: -0.4728, median: -0.6525
# step 900, discriminator loss: 0.7080, adversarial loss: 0.7041
# generated_images average: -0.3190, median: -0.4058
# step 1000, discriminator loss: 0.7123, adversarial loss: 0.6998
# generated_images average: -0.1529, median: -0.1153
# step 1100, discriminator loss: 0.7151, adversarial loss: 0.6948
# generated_images average: -0.0751, median: -0.0409
# step 1200, discriminator loss: 0.7173, adversarial loss: 0.6896
# generated_images average: -0.1159, median: -0.1403
# step 1300, discriminator loss: 0.7192, adversarial loss: 0.6858
# generated_images average: 0.0537, median: 0.0319
# step 1400, discriminator loss: 0.7211, adversarial loss: 0.6822
# generated_images average: -0.3066, median: -0.4304
# step 1500, discriminator loss: 0.7224, adversarial loss: 0.6777
# generated_images average: -0.2454, median: -0.3708
# step 1600, discriminator loss: 0.7234, adversarial loss: 0.6729
# generated_images average: -0.1061, median: -0.1518
# step 1700, discriminator loss: 0.7243, adversarial loss: 0.6689
# generated_images average: -0.3298, median: -0.4321
# step 1800, discriminator loss: 0.7251, adversarial loss: 0.6660
# generated_images average: -0.1417, median: -0.2305
# step 1900, discriminator loss: 0.7257, adversarial loss: 0.6624
# generated_images average: -0.2245, median: -0.3320
# step 2000, discriminator loss: 0.7264, adversarial loss: 0.6591
# generated_images average: -0.1581, median: -0.2103
# step 2100, discriminator loss: 0.7269, adversarial loss: 0.6564
# generated_images average: -0.2968, median: -0.3073
# step 2200, discriminator loss: 0.7272, adversarial loss: 0.6531
# generated_images average: -0.1884, median: -0.1867
# step 2300, discriminator loss: 0.7277, adversarial loss: 0.6502
# generated_images average: -0.3016, median: -0.3893
# step 2400, discriminator loss: 0.7279, adversarial loss: 0.6474
# generated_images average: -0.2839, median: -0.3062
# step 2500, discriminator loss: 0.7283, adversarial loss: 0.6444
# generated_images average: 0.0218, median: -0.0029
# step 2600, discriminator loss: 0.7285, adversarial loss: 0.6421
# generated_images average: -0.3113, median: -0.4319
# step 2700, discriminator loss: 0.7287, adversarial loss: 0.6402
# generated_images average: -0.0514, median: -0.0927
# step 2800, discriminator loss: 0.7290, adversarial loss: 0.6385
# generated_images average: -0.2005, median: -0.2245
# step 2900, discriminator loss: 0.7292, adversarial loss: 0.6366
# generated_images average: -0.4303, median: -0.5750
# step 3000, discriminator loss: 0.7295, adversarial loss: 0.6348
# generated_images average: -0.1064, median: -0.1536
# step 3100, discriminator loss: 0.7297, adversarial loss: 0.6339
# generated_images average: -0.5541, median: -0.8404
# step 3200, discriminator loss: 0.7298, adversarial loss: 0.6322
# generated_images average: -0.1564, median: -0.1729
# step 3300, discriminator loss: 0.7300, adversarial loss: 0.6314
# generated_images average: -0.3226, median: -0.4163
# step 3400, discriminator loss: 0.7300, adversarial loss: 0.6304
# generated_images average: -0.1445, median: -0.1266
# step 3500, discriminator loss: 0.7301, adversarial loss: 0.6291
# generated_images average: -0.3024, median: -0.4157
# step 3600, discriminator loss: 0.7302, adversarial loss: 0.6280
# generated_images average: -0.3222, median: -0.3494
# step 3700, discriminator loss: 0.7302, adversarial loss: 0.6269
# generated_images average: -0.2620, median: -0.2944
# step 3800, discriminator loss: 0.7302, adversarial loss: 0.6261
# generated_images average: -0.1114, median: -0.0947
# step 3900, discriminator loss: 0.7303, adversarial loss: 0.6253
# generated_images average: -0.5583, median: -0.7478
# step 4000, discriminator loss: 0.7303, adversarial loss: 0.6249
# generated_images average: -0.1681, median: -0.1613
# step 4100, discriminator loss: 0.7302, adversarial loss: 0.6242
# generated_images average: -0.4306, median: -0.6786
# step 4200, discriminator loss: 0.7302, adversarial loss: 0.6243
# generated_images average: -0.1050, median: -0.1273
# step 4300, discriminator loss: 0.7301, adversarial loss: 0.6233
# generated_images average: 0.0185, median: 0.0067
# step 4400, discriminator loss: 0.7301, adversarial loss: 0.6226
# generated_images average: -0.3111, median: -0.3696
# step 4500, discriminator loss: 0.7301, adversarial loss: 0.6221
# generated_images average: -0.3883, median: -0.4455
# step 4600, discriminator loss: 0.7300, adversarial loss: 0.6213
# generated_images average: -0.2184, median: -0.2968
# step 4700, discriminator loss: 0.7300, adversarial loss: 0.6208
# generated_images average: -0.1253, median: -0.0900
# step 4800, discriminator loss: 0.7299, adversarial loss: 0.6203
# generated_images average: -0.0352, median: -0.0309
# step 4900, discriminator loss: 0.7299, adversarial loss: 0.6200
# generated_images average: -0.1493, median: -0.1626
# step 5000, discriminator loss: 0.7298, adversarial loss: 0.6197
# generated_images average: -0.0630, median: -0.0495
# step 5100, discriminator loss: 0.7298, adversarial loss: 0.6194
# generated_images average: -0.0859, median: -0.0757
# step 5200, discriminator loss: 0.7298, adversarial loss: 0.6192
# generated_images average: -0.3479, median: -0.4794
# step 5300, discriminator loss: 0.7297, adversarial loss: 0.6191
# generated_images average: 0.0391, median: 0.0129
# step 5400, discriminator loss: 0.7297, adversarial loss: 0.6189
# generated_images average: -0.0257, median: -0.0199
# step 5500, discriminator loss: 0.7297, adversarial loss: 0.6187
# generated_images average: -0.1986, median: -0.1929
# step 5600, discriminator loss: 0.7296, adversarial loss: 0.6188
# generated_images average: -0.5246, median: -0.8070
# step 5700, discriminator loss: 0.7296, adversarial loss: 0.6188
# generated_images average: 0.1299, median: 0.1012
# step 5800, discriminator loss: 0.7295, adversarial loss: 0.6189
# generated_images average: -0.3235, median: -0.4415
# step 5900, discriminator loss: 0.7294, adversarial loss: 0.6189
# generated_images average: -0.1631, median: -0.1992
# step 6000, discriminator loss: 0.7294, adversarial loss: 0.6188
# generated_images average: -0.1567, median: -0.1491
# step 6100, discriminator loss: 0.7293, adversarial loss: 0.6189
# generated_images average: -0.0409, median: -0.0326
# step 6200, discriminator loss: 0.7293, adversarial loss: 0.6190
# generated_images average: -0.2213, median: -0.2602
# step 6300, discriminator loss: 0.7292, adversarial loss: 0.6192
# generated_images average: -0.1944, median: -0.3373
# step 6400, discriminator loss: 0.7292, adversarial loss: 0.6192
# generated_images average: -0.1184, median: -0.1374
# step 6500, discriminator loss: 0.7291, adversarial loss: 0.6195
# generated_images average: -0.2702, median: -0.2946
# step 6600, discriminator loss: 0.7290, adversarial loss: 0.6197
# generated_images average: -0.1077, median: -0.0928
# step 6700, discriminator loss: 0.7290, adversarial loss: 0.6198
# generated_images average: -0.1361, median: -0.1874
# step 6800, discriminator loss: 0.7290, adversarial loss: 0.6201
# generated_images average: -0.4760, median: -0.5168
# step 6900, discriminator loss: 0.7289, adversarial loss: 0.6204
# generated_images average: -0.0404, median: -0.0326
# step 7000, discriminator loss: 0.7289, adversarial loss: 0.6205
# generated_images average: -0.0506, median: -0.1060
# step 7100, discriminator loss: 0.7289, adversarial loss: 0.6207
# generated_images average: 0.0579, median: 0.0083
# step 7200, discriminator loss: 0.7288, adversarial loss: 0.6210
# generated_images average: -0.0640, median: -0.0797
# step 7300, discriminator loss: 0.7288, adversarial loss: 0.6212
# generated_images average: -0.0900, median: -0.2429
# step 7400, discriminator loss: 0.7288, adversarial loss: 0.6214
# generated_images average: -0.1831, median: -0.2016
# step 7500, discriminator loss: 0.7288, adversarial loss: 0.6216
# generated_images average: -0.1509, median: -0.2562
# step 7600, discriminator loss: 0.7288, adversarial loss: 0.6219
# generated_images average: -0.0927, median: -0.2003
# step 7700, discriminator loss: 0.7287, adversarial loss: 0.6220
# generated_images average: -0.3377, median: -0.4052
# step 7800, discriminator loss: 0.7287, adversarial loss: 0.6223
# generated_images average: -0.0076, median: -0.0340
# step 7900, discriminator loss: 0.7287, adversarial loss: 0.6226
# generated_images average: -0.2164, median: -0.2971
# step 8000, discriminator loss: 0.7286, adversarial loss: 0.6229
# generated_images average: -0.1988, median: -0.2674
# step 8100, discriminator loss: 0.7286, adversarial loss: 0.6232
# generated_images average: -0.4925, median: -0.7718
# step 8200, discriminator loss: 0.7285, adversarial loss: 0.6235
# generated_images average: -0.2173, median: -0.3099
# step 8300, discriminator loss: 0.7285, adversarial loss: 0.6238
# generated_images average: -0.0633, median: -0.0557
# step 8400, discriminator loss: 0.7285, adversarial loss: 0.6242
# generated_images average: -0.2545, median: -0.2823
# step 8500, discriminator loss: 0.7284, adversarial loss: 0.6244
# generated_images average: -0.3078, median: -0.3532
# step 8600, discriminator loss: 0.7284, adversarial loss: 0.6247
# generated_images average: -0.4417, median: -0.8741
# step 8700, discriminator loss: 0.7283, adversarial loss: 0.6250
# generated_images average: -0.0827, median: -0.1857
# step 8800, discriminator loss: 0.7283, adversarial loss: 0.6252
# generated_images average: -0.2062, median: -0.2291
# step 8900, discriminator loss: 0.7283, adversarial loss: 0.6257
# generated_images average: -0.1923, median: -0.2036
# step 9000, discriminator loss: 0.7282, adversarial loss: 0.6260
# generated_images average: -0.2604, median: -0.3174
# step 9100, discriminator loss: 0.7281, adversarial loss: 0.6265
# generated_images average: -0.1926, median: -0.2863
# step 9200, discriminator loss: 0.7281, adversarial loss: 0.6268
# generated_images average: -0.2818, median: -0.4825
# step 9300, discriminator loss: 0.7280, adversarial loss: 0.6272
# generated_images average: -0.0537, median: -0.0767
# step 9400, discriminator loss: 0.7280, adversarial loss: 0.6276
# generated_images average: -0.1670, median: -0.1831
# step 9500, discriminator loss: 0.7279, adversarial loss: 0.6279
# generated_images average: -0.2076, median: -0.3036
# step 9600, discriminator loss: 0.7279, adversarial loss: 0.6283
# generated_images average: -0.0824, median: -0.1783
# step 9700, discriminator loss: 0.7279, adversarial loss: 0.6287
# generated_images average: -0.2853, median: -0.3542
# step 9800, discriminator loss: 0.7279, adversarial loss: 0.6290
# generated_images average: 0.0503, median: 0.0869
# step 9900, discriminator loss: 0.7278, adversarial loss: 0.6293
# generated_images average: -0.1036, median: -0.1463

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')

plt.figure(figsize=(10, 6))
plt.plot(steps_plotted, d_losses, label='Discriminator Loss')
plt.plot(steps_plotted, a_losses, label='Adversarial Loss')
plt.title('GAN Training Loss')
plt.xlabel('Step')
plt.ylabel('Loss')
plt.legend()
plt.ylim(0.6, 0.8)
plt.grid(True)
plt.savefig('training_loss.png')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hlines(np.average(x_train), min(steps_plotted), max(steps_plotted), label='x_train average', color='red')
plt.hlines(np.median(x_train), min(steps_plotted), max(steps_plotted), label='x_train median', color='green')
plt.plot(steps_plotted, average, label='Generator output average', alpha = 0.5, color='red')
plt.plot(steps_plotted, median, label='Generator output median', alpha = 0.5, color='green')
plt.title('Train data vs generator output')
plt.xlabel('Step')
plt.ylabel('Value')
plt.legend()
plt.ylim(-1, 1)
plt.grid(True)
plt.savefig('average_median.png')
plt.show()

# %% [markdown]
# Let's display a few of our fake images:

# %%
import matplotlib.pyplot as plt

# Sample random points in the latent space
random_latent_vectors = np.random.normal(size=(10, latent_dim))

# Decode them to fake images
generated_images = generator.predict(random_latent_vectors)

for i in range(generated_images.shape[0]):
    img = image.array_to_img((generated_images[i] + 1) * 127.5, scale=False)
    plt.figure()
    plt.imshow(img)

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %% [markdown]
# Froggy with some pixellated artifacts.
