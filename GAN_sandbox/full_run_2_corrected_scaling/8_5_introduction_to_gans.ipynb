# %%
import keras
keras.__version__
# Out:
# '3.10.0'

# %% [markdown]
# # Introduction to generative adversarial networks
#
# This notebook contains the second code sample found in Chapter 8, Section 5 of [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python?a_aid=keras&a_bid=76564dff). Note that the original text features far more content, in particular further explanations and figures: in this notebook, you will only find source code and related comments.
#
# ---
# [...]

# %% [markdown]
# ## A schematic GAN implementation
#
#
# In what follows, we explain how to implement a GAN in Keras, in its barest form -- since GANs are quite advanced, diving deeply into the
# technical details would be out of scope for us. Our specific implementation will be a deep convolutional GAN, or DCGAN: a GAN where the
# generator and discriminator are deep convnets. In particular, it leverages a `Conv2DTranspose` layer for image upsampling in the generator.
#
# We will train our GAN on images from CIFAR10, a dataset of 50,000 32x32 RGB images belong to 10 classes (5,000 images per class). To make
# things even easier, we will only use images belonging to the class "frog".
#
# Schematically, our GAN looks like this:
#
# * A `generator` network maps vectors of shape `(latent_dim,)` to images of shape `(32, 32, 3)`.
# * A `discriminator` network maps images of shape (32, 32, 3) to a binary score estimating the probability that the image is real.
# * A `gan` network chains the generator and the discriminator together: `gan(x) = discriminator(generator(x))`. Thus this `gan` network maps
# latent space vectors to the discriminator's assessment of the realism of these latent vectors as decoded by the generator.
# * We train the discriminator using examples of real and fake images along with "real"/"fake" labels, as we would train any regular image
# classification model.
# * To train the generator, we use the gradients of the generator's weights with regard to the loss of the `gan` model. This means that, at
# every step, we move the weights of the generator in a direction that will make the discriminator more likely to classify as "real" the
# images decoded by the generator. I.e. we train the generator to fool the discriminator.

# %% [markdown]
# ## A bag of tricks
#
#
# Training GANs and tuning GAN implementations is notoriously difficult. There are a number of known "tricks" that one should keep in mind.
# Like most things in deep learning, it is more alchemy than science: these tricks are really just heuristics, not theory-backed guidelines.
# They are backed by some level of intuitive understanding of the phenomenon at hand, and they are known to work well empirically, albeit not
# necessarily in every context.
#
# Here are a few of the tricks that we leverage in our own implementation of a GAN generator and discriminator below. It is not an exhaustive
# list of GAN-related tricks; you will find many more across the GAN literature.
#
# * We use `tanh` as the last activation in the generator, instead of `sigmoid`, which would be more commonly found in other types of models.
# * We sample points from the latent space using a _normal distribution_ (Gaussian distribution), not a uniform distribution.
# * Stochasticity is good to induce robustness. Since GAN training results in a dynamic equilibrium, GANs are likely to get "stuck" in all sorts of ways.
# Introducing randomness during training helps prevent this. We introduce randomness in two ways: 1) we use dropout in the discriminator, 2)
# we add some random noise to the labels for the discriminator.
# * Sparse gradients can hinder GAN training. In deep learning, sparsity is often a desirable property, but not in GANs. There are two things
# that can induce gradient sparsity: 1) max pooling operations, 2) ReLU activations. Instead of max pooling, we recommend using strided
# convolutions for downsampling, and we recommend using a `LeakyReLU` layer instead of a ReLU activation. It is similar to ReLU but it
# relaxes sparsity constraints by allowing small negative activation values.
# * In generated images, it is common to see "checkerboard artifacts" caused by unequal coverage of the pixel space in the generator. To fix
# this, we use a kernel size that is divisible by the stride size, whenever we use a strided `Conv2DTranpose` or `Conv2D` in both the
# generator and discriminator.

# %% [markdown]
# ## The generator
#
#
# First, we develop a `generator` model, which turns a vector (from the latent space -- during training it will sampled at random) into a
# candidate image. One of the many issues that commonly arise with GANs is that the generator gets stuck with generated images that look like
# noise. A possible solution is to use dropout on both the discriminator and generator.

# %%
import keras
from keras import layers
import numpy as np

latent_dim = 32
height = 32
width = 32
channels = 3

generator_input = keras.Input(shape=(latent_dim,))

# First, transform the input into a 16x16 128-channels feature map
x = layers.Dense(128 * 16 * 16)(generator_input)
x = layers.LeakyReLU()(x)
x = layers.Reshape((16, 16, 128))(x)

# Then, add a convolution layer
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# Upsample to 32x32
x = layers.Conv2DTranspose(256, 4, strides=2, padding='same')(x)
x = layers.LeakyReLU()(x)

# Few more conv layers
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# Produce a 32x32 1-channel feature map
x = layers.Conv2D(channels, 7, activation='tanh', padding='same')(x)
generator = keras.models.Model(generator_input, x)
generator.summary()
# Out:
# Model: "functional_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_15 (InputLayer)     │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 32768)          │     1,081,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_45 (LeakyReLU)      │ (None, 32768)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_5 (Reshape)             │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_40 (Conv2D)              │ (None, 16, 16, 256)    │       819,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_46 (LeakyReLU)      │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_5              │ (None, 32, 32, 256)    │     1,048,832 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_47 (LeakyReLU)      │ (None, 32, 32, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_41 (Conv2D)              │ (None, 32, 32, 256)    │     1,638,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_48 (LeakyReLU)      │ (None, 32, 32, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_42 (Conv2D)              │ (None, 32, 32, 256)    │     1,638,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_49 (LeakyReLU)      │ (None, 32, 32, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_43 (Conv2D)              │ (None, 32, 32, 3)      │        37,635 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,264,579 (23.90 MB)
#  Trainable params: 6,264,579 (23.90 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## The discriminator
#
#
# Then, we develop a `discriminator` model, that takes as input a candidate image (real or synthetic) and classifies it into one of two
# classes, either "generated image" or "real image that comes from the training set".

# %%
discriminator_input = layers.Input(shape=(height, width, channels))
x = layers.Conv2D(128, 3)(discriminator_input)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Flatten()(x)

# One dropout layer - important trick!
x = layers.Dropout(0.4)(x)

# Classification layer
x = layers.Dense(1, activation='sigmoid')(x)

discriminator = keras.models.Model(discriminator_input, x)
discriminator.summary()

# To stabilize training, we use learning rate decay
# and gradient clipping (by value) in the optimizer.
discriminator_optimizer = keras.optimizers.RMSprop(learning_rate=0.0008, clipvalue=1.0)
discriminator.compile(optimizer=discriminator_optimizer, loss='binary_crossentropy')
# Out:
# Model: "functional_16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_16 (InputLayer)     │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_44 (Conv2D)              │ (None, 30, 30, 128)    │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_50 (LeakyReLU)      │ (None, 30, 30, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_45 (Conv2D)              │ (None, 14, 14, 128)    │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_51 (LeakyReLU)      │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_46 (Conv2D)              │ (None, 6, 6, 128)      │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_52 (LeakyReLU)      │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_47 (Conv2D)              │ (None, 2, 2, 128)      │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_53 (LeakyReLU)      │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 790,913 (3.02 MB)
#  Trainable params: 790,913 (3.02 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## The adversarial network
#
# Finally, we setup the GAN, which chains the generator and the discriminator. This is the model that, when trained, will move the generator
# in a direction that improves its ability to fool the discriminator. This model turns latent space points into a classification decision,
# "fake" or "real", and it is meant to be trained with labels that are always "these are real images". So training `gan` will updates the
# weights of `generator` in a way that makes `discriminator` more likely to predict "real" when looking at fake images. Very importantly, we
# set the discriminator to be frozen during training (non-trainable): its weights will not be updated when training `gan`. If the
# discriminator weights could be updated during this process, then we would be training the discriminator to always predict "real", which is
# not what we want!

# %%
# Set discriminator weights to non-trainable
# (will only apply to the `gan` model)
discriminator.trainable = False

gan_input = keras.Input(shape=(latent_dim,))
gan_output = discriminator(generator(gan_input))
gan = keras.models.Model(gan_input, gan_output)

gan_optimizer = keras.optimizers.RMSprop(learning_rate=0.0004, clipvalue=1.0)
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')
discriminator.trainable = True
# gan.load_weights('gan.weights.h5')

# %% [markdown]
# ## How to train your DCGAN
#
# Now we can start training. To recapitulate, this is schematically what the training loop looks like:
#
# ```
# for each epoch:
#     * Draw random points in the latent space (random noise).
#     * Generate images with `generator` using this random noise.
#     * Mix the generated images with real ones.
#     * Train `discriminator` using these mixed images, with corresponding targets, either "real" (for the real images) or "fake" (for the generated images).
#     * Draw new random points in the latent space.
#     * Train `gan` using these random vectors, with targets that all say "these are real images". This will update the weights of the generator (only, since discriminator is frozen inside `gan`) to move them towards getting the discriminator to predict "these are real images" for generated images, i.e. this trains the generator to fool the discriminator.
# ```
#
# Let's implement it:

# %%
import os
from keras.preprocessing import image

# Load CIFAR10 data
(x_train, y_train), (_, _) = keras.datasets.cifar10.load_data()

# Select frog images (class 6)
x_train = x_train[y_train.flatten() == 6]

# Normalize data
x_train = x_train.reshape(
    (x_train.shape[0],) + (height, width, channels)).astype('float32') / 127.5 - 1
print(f"x_train average: {np.average(x_train):.4f}, median: {np.median(x_train):.4f}")

iterations = 10000
batch_size = 20
save_dir = 'gan_images'
import shutil
shutil.rmtree(save_dir, ignore_errors=True)
os.makedirs(save_dir, exist_ok=True)
d_losses = []
a_losses = []
steps_plotted = []

# Start training loop
start = 0
for step in range(iterations):
    # Sample random points in the latent space
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # Decode them to fake images
    generated_images = generator.predict(random_latent_vectors, verbose=0)

    # Combine them with real images
    stop = start + batch_size
    real_images = x_train[start: stop]
    combined_images = np.concatenate([generated_images, real_images])

    # Assemble labels discriminating real from fake images
    labels = np.concatenate([np.ones((batch_size, 1)),
                             np.zeros((batch_size, 1))])
    # Add random noise to the labels - important trick!
    labels += 0.05 * np.random.random(labels.shape)

    # Train the discriminator
    d_loss = discriminator.train_on_batch(combined_images, labels)

    # sample random points in the latent space
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # Assemble labels that say "all real images"
    misleading_targets = np.zeros((batch_size, 1))

    # Train the generator (via the gan model,
    # where the discriminator weights are frozen)
    a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)
    d_losses.append(d_loss)
    a_losses.append(a_loss)
    steps_plotted.append(step)

    start += batch_size
    if start > len(x_train) - batch_size:
      start = 0

    # Occasionally save / plot
    if step % 100 == 0:
        # Save model weights
        gan.save_weights(f'gan_step_{step}.weights.h5')
        previous_file = f'gan_step_{step - 100}.weights.h5'
        if os.path.exists(previous_file):
            os.remove(previous_file)
        print(f'step {step}, discriminator loss: {d_loss:.4f}, adversarial loss: {a_loss:.4f}')
        print(f"generated_images average: {np.average(generated_images):.4f}, median: {np.median(generated_images):.4f}")

        # Save one generated image
        img = image.array_to_img((generated_images[0] + 1) * 127.5, scale=False)
        img.save(os.path.join(save_dir, 'generated_frog' + str(step) + '.png'))

        # Save one real image, for comparison
        img = image.array_to_img((real_images[0] + 1) * 127.5, scale=False)
        img.save(os.path.join(save_dir, 'real_frog' + str(step) + '.png'))
# Out:
# x_train average: -0.1642, median: -0.2000
# step 0, discriminator loss: 0.6923, adversarial loss: 0.6880
# generated_images average: -0.0023, median: -0.0020
# step 100, discriminator loss: 0.7715, adversarial loss: 0.7166
# generated_images average: -0.3371, median: -0.7064
# step 200, discriminator loss: 0.7276, adversarial loss: 0.7251
# generated_images average: -0.1333, median: -0.0349
# step 300, discriminator loss: 0.7255, adversarial loss: 0.7293
# generated_images average: -0.4626, median: -0.5100
# step 400, discriminator loss: 0.7229, adversarial loss: 0.7263
# generated_images average: -0.2760, median: -0.2707
# step 500, discriminator loss: 0.7211, adversarial loss: 0.7216
# generated_images average: -0.5519, median: -0.7309
# step 600, discriminator loss: 0.7203, adversarial loss: 0.7174
# generated_images average: -0.2130, median: -0.3584
# step 700, discriminator loss: 0.7196, adversarial loss: 0.7150
# generated_images average: -0.1823, median: -0.2144
# step 800, discriminator loss: 0.7181, adversarial loss: 0.7212
# generated_images average: -0.0658, median: 0.0369
# step 900, discriminator loss: 0.7177, adversarial loss: 0.7220
# generated_images average: -0.3051, median: -0.3414
# step 1000, discriminator loss: 0.7173, adversarial loss: 0.7229
# generated_images average: -0.2237, median: -0.2968
# step 1100, discriminator loss: 0.7172, adversarial loss: 0.7245
# generated_images average: -0.2663, median: -0.2732
# step 1200, discriminator loss: 0.7173, adversarial loss: 0.7268
# generated_images average: -0.1446, median: -0.2212
# step 1300, discriminator loss: 0.7178, adversarial loss: 0.7289
# generated_images average: 0.0788, median: 0.0402
# step 1400, discriminator loss: 0.7178, adversarial loss: 0.7297
# generated_images average: -0.1227, median: -0.1269
# step 1500, discriminator loss: 0.7177, adversarial loss: 0.7339
# generated_images average: -0.2028, median: -0.1943
# step 1600, discriminator loss: 0.7179, adversarial loss: 0.7360
# generated_images average: -0.3130, median: -0.4518
# step 1700, discriminator loss: 0.7182, adversarial loss: 0.7386
# generated_images average: -0.1362, median: -0.1213
# step 1800, discriminator loss: 0.7184, adversarial loss: 0.7410
# generated_images average: -0.1000, median: -0.0796
# step 1900, discriminator loss: 0.7186, adversarial loss: 0.7440
# generated_images average: -0.1418, median: -0.2368
# step 2000, discriminator loss: 0.7188, adversarial loss: 0.7472
# generated_images average: -0.2951, median: -0.2826
# step 2100, discriminator loss: 0.7191, adversarial loss: 0.7497
# generated_images average: -0.1138, median: -0.0708
# step 2200, discriminator loss: 0.7192, adversarial loss: 0.7519
# generated_images average: -0.2755, median: -0.3090
# step 2300, discriminator loss: 0.7192, adversarial loss: 0.7546
# generated_images average: -0.1596, median: -0.1467
# step 2400, discriminator loss: 0.7194, adversarial loss: 0.7573
# generated_images average: -0.1545, median: -0.1374
# step 2500, discriminator loss: 0.7195, adversarial loss: 0.7599
# generated_images average: -0.2180, median: -0.2841
# step 2600, discriminator loss: 0.7197, adversarial loss: 0.7624
# generated_images average: -0.1292, median: -0.1947
# step 2700, discriminator loss: 0.7199, adversarial loss: 0.7642
# generated_images average: -0.3187, median: -0.3415
# step 2800, discriminator loss: 0.7203, adversarial loss: 0.7663
# generated_images average: -0.0815, median: -0.0463
# step 2900, discriminator loss: 0.7207, adversarial loss: 0.7687
# generated_images average: -0.3131, median: -0.3825
# step 3000, discriminator loss: 0.7209, adversarial loss: 0.7708
# generated_images average: -0.1864, median: -0.2327
# step 3100, discriminator loss: 0.7212, adversarial loss: 0.7731
# generated_images average: -0.2263, median: -0.2014
# step 3200, discriminator loss: 0.7213, adversarial loss: 0.7751
# generated_images average: -0.0724, median: -0.0580
# step 3300, discriminator loss: 0.7216, adversarial loss: 0.7769
# generated_images average: -0.2173, median: -0.2023
# step 3400, discriminator loss: 0.7217, adversarial loss: 0.7785
# generated_images average: -0.1780, median: -0.1918
# step 3500, discriminator loss: 0.7219, adversarial loss: 0.7800
# generated_images average: -0.3960, median: -0.5120
# step 3600, discriminator loss: 0.7229, adversarial loss: 0.7815
# generated_images average: -0.1023, median: -0.1130
# step 3700, discriminator loss: 0.7229, adversarial loss: 0.7842
# generated_images average: -0.2466, median: -0.2819
# step 3800, discriminator loss: 0.7254, adversarial loss: 0.7868
# generated_images average: -0.6099, median: -0.8079
# step 3900, discriminator loss: 0.7259, adversarial loss: 0.7884
# generated_images average: -0.1715, median: -0.1405
# step 4000, discriminator loss: 0.7259, adversarial loss: 0.7903
# generated_images average: -0.0703, median: -0.0978
# step 4100, discriminator loss: 0.7258, adversarial loss: 0.7926
# generated_images average: -0.1479, median: -0.1586
# step 4200, discriminator loss: 0.7260, adversarial loss: 0.7964
# generated_images average: -0.1350, median: -0.1593
# step 4300, discriminator loss: 0.7272, adversarial loss: 0.7975
# generated_images average: -0.0612, median: -0.0302
# step 4400, discriminator loss: 0.7276, adversarial loss: 0.7994
# generated_images average: -0.1294, median: -0.1359
# step 4500, discriminator loss: 0.7279, adversarial loss: 0.8005
# generated_images average: -0.1589, median: -0.1412
# step 4600, discriminator loss: 0.7282, adversarial loss: 0.8019
# generated_images average: -0.2416, median: -0.2455
# step 4700, discriminator loss: 0.7287, adversarial loss: 0.8038
# generated_images average: -0.1484, median: -0.1686
# step 4800, discriminator loss: 0.7288, adversarial loss: 0.8087
# generated_images average: -0.0191, median: 0.0050
# step 4900, discriminator loss: 0.7295, adversarial loss: 0.8104
# generated_images average: -0.3006, median: -0.5178
# step 5000, discriminator loss: 0.7298, adversarial loss: 0.8114
# generated_images average: -0.1236, median: -0.1589
# step 5100, discriminator loss: 0.7299, adversarial loss: 0.8126
# generated_images average: -0.0688, median: -0.1111
# step 5200, discriminator loss: 0.7316, adversarial loss: 0.8141
# generated_images average: -0.0830, median: -0.0886
# step 5300, discriminator loss: 0.7324, adversarial loss: 0.8250
# generated_images average: -0.0998, median: -0.0445
# step 5400, discriminator loss: 0.7325, adversarial loss: 0.8259
# generated_images average: -0.1724, median: -0.1590
# step 5500, discriminator loss: 0.7326, adversarial loss: 0.8271
# generated_images average: -0.1778, median: -0.1964
# step 5600, discriminator loss: 0.7326, adversarial loss: 0.8281
# generated_images average: -0.0584, median: -0.0594
# step 5700, discriminator loss: 0.7326, adversarial loss: 0.8293
# generated_images average: -0.1766, median: -0.2142
# step 5800, discriminator loss: 0.7327, adversarial loss: 0.8302
# generated_images average: -0.1678, median: -0.2263
# step 5900, discriminator loss: 0.7331, adversarial loss: 0.8313
# generated_images average: -0.2075, median: -0.1953
# step 6000, discriminator loss: 0.7341, adversarial loss: 0.8329
# generated_images average: -0.0893, median: -0.1064
# step 6100, discriminator loss: 0.7342, adversarial loss: 0.8342
# generated_images average: -0.1983, median: -0.2275
# step 6200, discriminator loss: 0.7344, adversarial loss: 0.8353
# generated_images average: -0.1667, median: -0.2274
# step 6300, discriminator loss: 0.7345, adversarial loss: 0.8380
# generated_images average: -0.0547, median: -0.0463
# step 6400, discriminator loss: 0.7346, adversarial loss: 0.8395
# generated_images average: -0.1884, median: -0.1935
# step 6500, discriminator loss: 0.7346, adversarial loss: 0.8404
# generated_images average: -0.1577, median: -0.1815
# step 6600, discriminator loss: 0.7347, adversarial loss: 0.8411
# generated_images average: -0.1460, median: -0.2690
# step 6700, discriminator loss: 0.7351, adversarial loss: 0.8419
# generated_images average: -0.0668, median: -0.1021
# step 6800, discriminator loss: 0.7359, adversarial loss: 0.8429
# generated_images average: -0.1081, median: -0.1024
# step 6900, discriminator loss: 0.7360, adversarial loss: 0.8438
# generated_images average: -0.1316, median: -0.2106
# step 7000, discriminator loss: 0.7363, adversarial loss: 0.8451
# generated_images average: -0.2634, median: -0.2452
# step 7100, discriminator loss: 0.7365, adversarial loss: 0.8462
# generated_images average: -0.2137, median: -0.2010
# step 7200, discriminator loss: 0.7367, adversarial loss: 0.8477
# generated_images average: -0.1049, median: -0.1800
# step 7300, discriminator loss: 0.7368, adversarial loss: 0.8486
# generated_images average: -0.2000, median: -0.2132
# step 7400, discriminator loss: 0.7369, adversarial loss: 0.8496
# generated_images average: -0.2542, median: -0.3214
# step 7500, discriminator loss: 0.7370, adversarial loss: 0.8507
# generated_images average: -0.1592, median: -0.2276
# step 7600, discriminator loss: 0.7371, adversarial loss: 0.8554
# generated_images average: -0.1415, median: -0.1809
# step 7700, discriminator loss: 0.7371, adversarial loss: 0.8562
# generated_images average: -0.1861, median: -0.2598
# step 7800, discriminator loss: 0.7372, adversarial loss: 0.8572
# generated_images average: -0.2028, median: -0.2208
# step 7900, discriminator loss: 0.7373, adversarial loss: 0.8579
# generated_images average: -0.2201, median: -0.2639
# step 8000, discriminator loss: 0.7373, adversarial loss: 0.8587
# generated_images average: -0.1815, median: -0.2610
# step 8100, discriminator loss: 0.7374, adversarial loss: 0.8594
# generated_images average: -0.1401, median: -0.1414
# step 8200, discriminator loss: 0.7374, adversarial loss: 0.8601
# generated_images average: -0.1179, median: -0.1192
# step 8300, discriminator loss: 0.7375, adversarial loss: 0.8611
# generated_images average: -0.1939, median: -0.1810
# step 8400, discriminator loss: 0.7376, adversarial loss: 0.8619
# generated_images average: -0.0728, median: -0.0507
# step 8500, discriminator loss: 0.7374, adversarial loss: 0.8625
# generated_images average: -0.2556, median: -0.2724
# step 8600, discriminator loss: 0.7376, adversarial loss: 0.8632
# generated_images average: -0.0865, median: -0.1098
# step 8700, discriminator loss: 0.7377, adversarial loss: 0.8643
# generated_images average: -0.1696, median: -0.2557
# step 8800, discriminator loss: 0.7377, adversarial loss: 0.8648
# generated_images average: -0.0090, median: 0.0045
# step 8900, discriminator loss: 0.7378, adversarial loss: 0.8655
# generated_images average: -0.0469, median: -0.0353
# step 9000, discriminator loss: 0.7378, adversarial loss: 0.8659
# generated_images average: -0.1441, median: -0.1284
# step 9100, discriminator loss: 0.7379, adversarial loss: 0.8667
# generated_images average: -0.1469, median: -0.1568
# step 9200, discriminator loss: 0.7385, adversarial loss: 0.8671
# generated_images average: -0.1562, median: -0.1159
# step 9300, discriminator loss: 0.7386, adversarial loss: 0.8680
# generated_images average: -0.1963, median: -0.2062
# step 9400, discriminator loss: 0.7387, adversarial loss: 0.8689
# generated_images average: -0.2218, median: -0.2559
# step 9500, discriminator loss: 0.7387, adversarial loss: 0.8693
# generated_images average: -0.2264, median: -0.2629
# step 9600, discriminator loss: 0.7388, adversarial loss: 0.8705
# generated_images average: -0.1646, median: -0.1629
# step 9700, discriminator loss: 0.7387, adversarial loss: 0.8712
# generated_images average: -0.0216, median: -0.0707
# step 9800, discriminator loss: 0.7387, adversarial loss: 0.8725
# generated_images average: 0.0226, median: 0.0638
# step 9900, discriminator loss: 0.7389, adversarial loss: 0.8729
# generated_images average: -0.2102, median: -0.2374

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')

plt.figure(figsize=(10, 6))
plt.plot(steps_plotted, d_losses, label='Discriminator Loss')
plt.plot(steps_plotted, a_losses, label='Adversarial Loss')
plt.title('GAN Training Loss')
plt.xlabel('Step')
plt.ylabel('Loss')
plt.legend()
plt.ylim(0.6, 1)
plt.grid(True)
plt.savefig('training_loss.png')
plt.show()

# %% [markdown]
# Let's display a few of our fake images:

# %%
import matplotlib.pyplot as plt

# Sample random points in the latent space
random_latent_vectors = np.random.normal(size=(10, latent_dim))

# Decode them to fake images
generated_images = generator.predict(random_latent_vectors)

for i in range(generated_images.shape[0]):
    img = image.array_to_img((generated_images[i] + 1) * 127.5, scale=False)
    plt.figure()
    plt.imshow(img)

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %% [markdown]
# Froggy with some pixellated artifacts.
